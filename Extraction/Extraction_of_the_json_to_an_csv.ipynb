# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json


with open('/content/drive/My Drive/Procesamiento de Datos/Parcial/season_stats.json') as file:
    json_data = json.load(file)
teams_list = []
aggregate_stats_list = []
players_list = []

for match_id, teams in json_data.items():
    for team_id, team_info in teams.items():
        team_details = team_info['team_details']
        team_details['match_id'] = match_id
        team_details['team_id'] = team_id
        teams_list.append(team_details)
        aggregate_stats = team_info['aggregate_stats']
        aggregate_stats['match_id'] = match_id
        aggregate_stats['team_id'] = team_id
        aggregate_stats_list.append(aggregate_stats)
        for player_name, player_info in team_info['Player_stats'].items():
            player_stats = player_info['Match_stats']
            player_stats.update(player_info['player_details'])
            player_stats['match_id'] = match_id
            player_stats['team_id'] = team_id
            player_stats['player_name'] = player_name
            players_list.append(player_stats)

df_team_details = pd.DataFrame(teams_list)
df_aggregate_stats = pd.DataFrame(aggregate_stats_list)
df_player_stats = pd.DataFrame(players_list)

# %%
df_teams
# Out:
#     team_id          team_name       team_rating        date match_id
# 0       166       Huddersfield              6.14  30/01/2018  1190418
# 1        26          Liverpool  7.22285714285714  30/01/2018  1190418
# 2       211           Brighton  7.15384615384615  01/01/2018  1190424
# 3       183        Bournemouth  6.90285714285714  01/01/2018  1190424
# 4        15            Chelsea  6.77142857142857  13/01/2018  1190342
# ..      ...                ...               ...         ...      ...
# 755      27            Watford  6.17071428571429  11/03/2018  1190373
# 756      32  Manchester United  7.31928571428571  03/02/2018  1190367
# 757     166       Huddersfield  6.40857142857143  03/02/2018  1190367
# 758      96              Stoke  6.31076923076923  12/03/2018  1190401
# 759     167    Manchester City  7.23769230769231  12/03/2018  1190401
#
# [760 rows x 5 columns]

# %%
df_aggregate_stats
# Out:
#     won_corners att_sv_low_centre won_contest total_tackle aerial_lost  \
# 0             1                 1           5           11          15
# 1             4                 2           6           13          16
# 2             5                 1          12           23          16
# 3            12                 3          17            6          25
# 4             6                 1          15           13          18
# ..          ...               ...         ...          ...         ...
# 755           9                 1           7           13          22
# 756           5                 3          27           15          18
# 757           2               NaN           4           22          14
# 758           3               NaN           9           19          16
# 759          10                 1          10           16          13
#
#     possession_percentage accurate_pass total_pass total_throws  \
# ...

# %%
df_players
# Out:
#       good_high_claim touches saves total_pass formation_place accurate_pass  \
# 0                   2      39     4         28               1            11
# 1                 NaN      30   NaN         20               4            16
# 2                 NaN      38   NaN         15               3             6
# 3                 NaN      44   NaN         28               6            27
# 4                 NaN      46   NaN         27               5            21
# ...               ...     ...   ...        ...             ...           ...
# 13670             NaN     NaN   NaN        NaN               0           NaN
# 13671             NaN     NaN   NaN        NaN               0           NaN
# 13672             NaN     NaN   NaN        NaN               0           NaN
# 13673             NaN     NaN   NaN        NaN               0           NaN
# 13674             NaN       9   NaN          8               0             8
#
# ...

# %%
team_details_filtered = df_team_details[(df_team_details['match_id'] == '1190418') &
                                        (df_team_details['team_id'] == '166')]


aggregate_stats_filtered = df_aggregate_stats[(df_aggregate_stats['match_id'] == '1190418') &
                                              (df_aggregate_stats['team_id'] == '166')]
player_stats_filtered = df_player_stats[(df_player_stats['match_id'] == '1190418') &
                                        (df_player_stats['team_id'] == '166')]


print("\nPlayer Stats for team_id 166 and match_id 1190418:")
print(player_stats_filtered)
# Out:
# Player Stats for team_id 166 and match_id 1190418:
#    good_high_claim touches saves total_pass formation_place accurate_pass  \
# 0                2      39     4         28               1            11
# 1              NaN      30   NaN         20               4            16
# 2              NaN      38   NaN         15               3             6
# 3              NaN      44   NaN         28               6            27
# 4              NaN      46   NaN         27               5            21
# 5              NaN      54   NaN         27               2            15
# 6              NaN      44   NaN         30              11            26
# 7              NaN      47   NaN         36               7            27
# 8              NaN      53   NaN         43               8            31
# 9              NaN      40   NaN         25              10            14
# 10             NaN      16   NaN          9               9             6
# ...

# %%
df_team_details.to_csv("Team details")
df_aggregate_stats.to_csv("Stats_of_the_match")
df_player_stats.to_csv("Player_stats")
